# %%
from refactored_utils import get_and_prepare_data
from segment_plot import create_and_plot_segment_plot
from sample_heatmap import create_and_plot_sample_heatmap
from overlap_plots import create_and_plot_overlap_plot, create_and_plot_overlap_heat_map_and_gradient_heatmap

data_path = 'protein-peptides.csv'
df = get_and_prepare_data(data_path)
# get number of different proteins
protein_ids = df['Protein Accession'].unique()
print(f'Number of different proteins: {len(protein_ids)}')
create_and_plot_segment_plot(df, prspacing = 0.2, color_scale ='Blues', is_log_scaled=True)
# Out:
# peptide mismatch
# Number of different protein IDs: 583
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-117959a4a65c> in <module>
#       9 protein_ids = df['Protein Accession'].unique()
#      10 print(f'Number of different protein IDs: {len(protein_ids)}')
# ---> 11 create_and_plot_segment_plot(df, spacing = 0.2, color_scale ='Blues', is_log_scaled=True)
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in create_and_plot_segment_plot(df, _protein, spacing, colors, color_scale, is_log_scaled)
#     353 """
#     354 def create_and_plot_segment_plot(df, _protein="P02666", spacing=0, colors = True, color_scale='Greys', is_log_scaled = True):
# --> 355     peptide_patches, mod_patches, height = create_data_for_segment_plot(df, _protein, spacing=spacing, colors=colors, color_scale=color_scale, is_log_scaled=is_log_scaled)
#     356     plot_peptide_segments(peptide_patches, mod_patches, height, colors = colors, color_scale=color_scale, is_log_scaled=is_log_scaled)
#     357
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in create_data_for_segment_plot(df, _protein, spacing, colors, color_scale, is_log_scaled)
#     360     data = preprocess_data_for_peptide_segment_plot(df, _protein)
#     361     rectangles_and_mods = get_rectangles_for_peptides_and_mods(data)
# --> 362     rectangles_and_mods = stack_recs(rectangles_and_mods, colors=colors, color_scale=color_scale, is_log_scaled=is_log_scaled)
#     363     # peptide_patches, mod_patches, height = get_stacking_patch_attributes(rectangles_and_mods, spacing = spacing)
#     364     peptide_patches, mod_patches, height = get_stacking_patches(rectangles_and_mods, spacing = spacing)
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in stack_recs(rectangles_and_mods, colors, color_scale, is_log_scaled)
#     140
#     141     if colors:
# --> 142         rects_and_attribute = map_to_colors(res_intensities, res_rectangles_and_mods, color_scale = color_scale, is_log_scaled=is_log_scaled)
#     143     else:
#     144         rects_and_attribute = map_to_norm_intensities(res_intensities, res_rectangles_and_mods)
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in map_to_colors(res_intensities, res_rectangles_and_mods, color_scale, is_log_scaled)
#      93 def map_to_colors(res_intensities, res_rectangles_and_mods, color_scale = 'Greys', is_log_scaled = True):
#      94     rects = [r[0] for r in res_rectangles_and_mods]
# ---> 95     color_values = colors_(res_intensities, color_scale=color_scale, is_log_scaled=is_log_scaled)
#      96     rects_and_colors = list(zip(rects, color_values))
#      97     mods = [r[1] for r in res_rectangles_and_mods]
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in colors_(values, color_scale, is_log_scaled)
#      85
#      86 def colors_(values: list , color_scale = 'Greys', is_log_scaled = True):
# ---> 87     normalized = normalize(values, is_log_scaled,  min_val=0.2)
#      88     cmap = plt.cm.get_cmap(color_scale)
#      89     color_list = [cls.rgb2hex(cmap(i)) for i in normalized]
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in normalize(res_intensities, is_log_scaled, min_val)
#      80     if is_log_scaled:
#      81         values = np.log(values)
# ---> 82     values = (values - min(values)) / (max(values) - min(values)) # normalize
#      83     normalized = values * (1 - min_val) + min_val
#      84     return normalized
#
# ValueError: min() arg is an empty sequence
