# %%
from refactored_utils import get_and_prepare_data
from segment_plot import create_and_plot_segment_plot
from sample_heatmap import create_and_plot_sample_heatmap
from overlap_plots import create_and_plot_overlap_plot, create_and_plot_overlap_heat_map_and_gradient_heatmap

data_path = 'protein-peptides.csv'
df = get_and_prepare_data(data_path)
# get number of different proteins
protein_ids = df['Protein Accession'].unique()
print(f'Number of different proteins: {len(protein_ids)}')
protein = "P63258|ACTG_BOVIN"
print(df.describe(include='all'))
create_and_plot_segment_plot(df,_protein = protein, spacing = 0.2, color_scale ='Blues', is_log_scaled=True, is_stacked=False)
# Out:
# Number of different proteins: 583
#          Protein Accession                   Peptide               PTM  \
# count                 6886                      6886              4059
# unique                 583                      6259                42
# top     P02663|CASA2_BOVIN  R.VVEQMC(+57.02)ITQYQR.E  Deamidation (NQ)
# freq                   380                        23              1330
# mean                   NaN                       NaN               NaN
# std                    NaN                       NaN               NaN
# min                    NaN                       NaN               NaN
# 25%                    NaN                       NaN               NaN
# 50%                    NaN                       NaN               NaN
# 75%                    NaN                       NaN               NaN
# max                    NaN                       NaN               NaN
#
#               Start          End       Length  Area Sample 1  Area Sample 2  \
# count   6886.000000  6886.000000  6886.000000   3.917000e+03   3.804000e+03
# unique          NaN          NaN          NaN            NaN            NaN
# top             NaN          NaN          NaN            NaN            NaN
# freq            NaN          NaN          NaN            NaN            NaN
# mean     262.885274   278.395440    16.510166   1.014917e+05   1.063610e+05
# std      300.507933   300.337756     6.714305   7.914053e+05   8.670504e+05
# min        1.000000    12.000000     7.000000   0.000000e+00   0.000000e+00
# 25%       87.000000   104.000000    12.000000   7.228500e+02   7.762975e+02
# 50%      166.000000   180.000000    15.000000   2.445500e+03   2.514900e+03
# 75%      322.000000   338.000000    20.000000   1.102400e+04   1.174025e+04
# max     2485.000000  2507.000000    65.000000   2.912100e+07   3.413300e+07
#
#         Area Sample 3  Area Sample 4  ...  Area Sample 10  Area Sample 11  \
# count    3.584000e+03   3.492000e+03  ...    3.238000e+03    3.461000e+03
# unique            NaN            NaN  ...             NaN             NaN
# top               NaN            NaN  ...             NaN             NaN
# freq              NaN            NaN  ...             NaN             NaN
# mean     1.180105e+05   1.111799e+05  ...    1.169749e+05    1.160323e+05
# std      8.817709e+05   8.534171e+05  ...    8.336135e+05    8.270073e+05
# min      0.000000e+00   0.000000e+00  ...    0.000000e+00    0.000000e+00
# 25%      7.846875e+02   7.902800e+02  ...    8.308850e+02    8.515400e+02
# 50%      2.741900e+03   2.706650e+03  ...    3.141450e+03    2.876100e+03
# 75%      1.387200e+04   1.364375e+04  ...    1.614925e+04    1.369000e+04
# max      2.710400e+07   3.163700e+07  ...    3.066400e+07    2.719400e+07
#
#         Area Sample 12  Area Sample 13  Area Sample 14  Area Sample 15  \
# count     3.510000e+03    3.025000e+03    3.089000e+03    3.221000e+03
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean      1.152343e+05    1.136288e+05    1.156566e+05    1.094374e+05
# std       8.282763e+05    8.200328e+05    8.508625e+05    8.606934e+05
# min       0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# LLLLL [(((18, 10, 0.10713375581412327), '#083c7d'), []), (((28, 11, 0.14494619794104574), '#08326e'), []), (((39, 11, 0.035829975812747675), '#135fa7'), []), (((39, 11, 0.00341296070049002), '#61a7d2'), [(4, '#3CB44B', 0.00341296070049002)]), (((39, 11, 0.0005774359750498869), '#b3d3e8'), [(4, '#3CB44B', 0.0005774359750498869)]), (((39, 11, 0.007815349749885661), '#4090c5'), [(7, '#3CB44B', 0.007815349749885661)]), (((39, 11, 0.003544112946230376), '#60a7d2'), [(9, '#F032E6', 0.003544112946230376)]), (((50, 12, 0.000497819128812932), '#b8d5ea'), []), (((50, 11, 0.02449616534287408), '#1c6bb0'), []), (((50, 11, 0.009493547643955073), '#3a8ac2'), [(8, '#F032E6', 0.009493547643955073)]), (((84, 11, 0.09668032393244676), '#084082'), []), (((95, 18, 0.11608534778794798), '#083979'), []), (((147, 30, 0.028153185720381616), '#1967ad'), []), (((183, 8, 0.04883750209381272), '#0b559f'), []), (((196, 10, 0.06976858107973737), '#084a91'), []), (((215, 23, 0.1576286106951855), '#08306b'), [(1, '#FFE119', 0.1576286106951855)]), (((215, 23, 0.00036361325027212615), '#c4daee'), [(1, '#FFE119', 0.00036361325027212615), (9, '#F032E6', 0.00036361325027212615)]), (((215, 23, 0.00023210175361407066), '#d0e1f2'), [(1, '#FFE119', 0.00023210175361407066), (11, '#3CB44B', 0.00023210175361407066)]), (((238, 16, 0.011041961867208698), '#3585bf'), []), (((256, 28, 0.001712420820776979), '#82bbdb'), [(0, '#FFE119', 0.001712420820776979)]), (((284, 7, 0.005665044828398709), '#4d99ca'), [(0, '#FFE119', 0.005665044828398709)]), (((291, 21, 0.022116598460741543), '#1f6eb3'), []), (((291, 21, 0.044034839093352984), '#0e59a2'), [(13, '#3CB44B', 0.044034839093352984)]), (((315, 11, 0.03087618792624212), '#1764ab'), []), (((328, 8, 0.0010814307982099484), '#99c7e0'), []), (((359, 13, 0.027974928836456164), '#1967ad'), [])]

# %%
from refactored_utils import get_and_prepare_data
from segment_plot import create_and_plot_segment_plot
from sample_heatmap import create_and_plot_sample_heatmap
from overlap_plots import create_and_plot_overlap_plot, create_and_plot_overlap_heat_map_and_gradient_heatmap

data_path = 'protein-peptides.csv'
df = get_and_prepare_data(data_path)
# get number of different proteins
protein_ids = df['Protein Accession'].unique()
print(f'Number of different proteins: {len(protein_ids)}')
protein = "P63258|ACTG_BOVIN"
print(df.describe(include='all'))
create_and_plot_segment_plot(df,_protein = protein, spacing = 0.2, color_scale ='Blues', is_log_scaled=True, is_stacked=True)
# Out:
# Number of different proteins: 583
#          Protein Accession                   Peptide               PTM  \
# count                 6886                      6886              4059
# unique                 583                      6259                42
# top     P02663|CASA2_BOVIN  R.VVEQMC(+57.02)ITQYQR.E  Deamidation (NQ)
# freq                   380                        23              1330
# mean                   NaN                       NaN               NaN
# std                    NaN                       NaN               NaN
# min                    NaN                       NaN               NaN
# 25%                    NaN                       NaN               NaN
# 50%                    NaN                       NaN               NaN
# 75%                    NaN                       NaN               NaN
# max                    NaN                       NaN               NaN
#
#               Start          End       Length  Area Sample 1  Area Sample 2  \
# count   6886.000000  6886.000000  6886.000000   3.917000e+03   3.804000e+03
# unique          NaN          NaN          NaN            NaN            NaN
# top             NaN          NaN          NaN            NaN            NaN
# freq            NaN          NaN          NaN            NaN            NaN
# mean     262.885274   278.395440    16.510166   1.014917e+05   1.063610e+05
# std      300.507933   300.337756     6.714305   7.914053e+05   8.670504e+05
# min        1.000000    12.000000     7.000000   0.000000e+00   0.000000e+00
# 25%       87.000000   104.000000    12.000000   7.228500e+02   7.762975e+02
# 50%      166.000000   180.000000    15.000000   2.445500e+03   2.514900e+03
# 75%      322.000000   338.000000    20.000000   1.102400e+04   1.174025e+04
# max     2485.000000  2507.000000    65.000000   2.912100e+07   3.413300e+07
#
#         Area Sample 3  Area Sample 4  ...  Area Sample 10  Area Sample 11  \
# count    3.584000e+03   3.492000e+03  ...    3.238000e+03    3.461000e+03
# unique            NaN            NaN  ...             NaN             NaN
# top               NaN            NaN  ...             NaN             NaN
# freq              NaN            NaN  ...             NaN             NaN
# mean     1.180105e+05   1.111799e+05  ...    1.169749e+05    1.160323e+05
# std      8.817709e+05   8.534171e+05  ...    8.336135e+05    8.270073e+05
# min      0.000000e+00   0.000000e+00  ...    0.000000e+00    0.000000e+00
# 25%      7.846875e+02   7.902800e+02  ...    8.308850e+02    8.515400e+02
# 50%      2.741900e+03   2.706650e+03  ...    3.141450e+03    2.876100e+03
# 75%      1.387200e+04   1.364375e+04  ...    1.614925e+04    1.369000e+04
# max      2.710400e+07   3.163700e+07  ...    3.066400e+07    2.719400e+07
#
#         Area Sample 12  Area Sample 13  Area Sample 14  Area Sample 15  \
# count     3.510000e+03    3.025000e+03    3.089000e+03    3.221000e+03
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean      1.152343e+05    1.136288e+05    1.156566e+05    1.094374e+05
# std       8.282763e+05    8.200328e+05    8.508625e+05    8.606934e+05
# min       0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 25%       8.087425e+02    9.153800e+02    8.457700e+02    7.661900e+02
# 50%       2.762450e+03    3.016900e+03    2.831700e+03    2.855900e+03
# 75%       1.379225e+04    1.489400e+04    1.437800e+04    1.347000e+04
# max       2.715400e+07    2.852600e+07    2.949700e+07    3.281000e+07
#
#         Area Sample 16  Area Sample 17  Area Sample 18  #modifications
# count     2.592000e+03    2.959000e+03    3.049000e+03     4059.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean      1.150037e+05    1.128050e+05    1.108106e+05        1.352550
# std       9.287085e+05    8.383167e+05    8.357893e+05        0.544361
# min       0.000000e+00    0.000000e+00    0.000000e+00        1.000000
# 25%       7.734550e+02    8.283700e+02    8.260700e+02        1.000000
# 50%       2.870700e+03    2.754000e+03    2.851400e+03        1.000000
# 75%       1.313800e+04    1.491500e+04    1.457500e+04        2.000000
# max       3.200100e+07    2.980700e+07    3.016600e+07        4.000000
#
# [11 rows x 25 columns]
