# %%
from refactored_utils import get_and_prepare_data
from segment_plot import create_and_plot_segment_plot
from sample_heatmap import create_and_plot_sample_heatmap
from overlap_plots import create_and_plot_overlap_plot, create_and_plot_overlap_heat_map_and_gradient_heatmap

df = get_and_prepare_data()
create_and_plot_segment_plot(df, spacing = 0.2, color_scale ='Blues', is_log_scaled=True)
# Out:
# In /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
create_and_plot_overlap_plot(df)

# %%
create_and_plot_overlap_heat_map_and_gradient_heatmap(df)

# %%
create_and_plot_sample_heatmap(df)

# %%
from refactored_utils import get_and_prepare_data
from segment_plot import create_and_plot_segment_plot
from sample_heatmap import create_and_plot_sample_heatmap
from overlap_plots import create_and_plot_overlap_plot, create_and_plot_overlap_heat_map_and_gradient_heatmap

df = get_and_prepare_data()
create_and_plot_segment_plot(df, spacing = 0.2, is_log_scaled=True, colors = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-bdadd3ebc60b> in <module>
#       5
#       6 df = get_and_prepare_data()
# ----> 7 create_and_plot_segment_plot(df, spacing = 0.2, is_log_scaled=True, colors = False)
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in create_and_plot_segment_plot(df, _protein, spacing, colors, color_scale, is_log_scaled)
#     361 """
#     362 def create_and_plot_segment_plot(df, _protein="P02666", spacing=0, colors = True, color_scale='Greys', is_log_scaled = True):
# --> 363     peptide_patches, mod_patches, height, seqq, modification_color_map = create_data_for_segment_plot(df, _protein, spacing=spacing, colors=colors, color_scale=color_scale, is_log_scaled=is_log_scaled)
#     364     plot_peptide_segments(peptide_patches, mod_patches, height, modification_color_map, colors = colors, color_scale=color_scale, is_log_scaled=is_log_scaled, _protein = _protein)
#     365
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in create_data_for_segment_plot(df, _protein, spacing, colors, color_scale, is_log_scaled)
#     376
#     377     # peptide_patches, mod_patches, height = get_stacking_patch_attributes(rectangles_and_mods, spacing = spacing)
# --> 378     peptide_patches, mod_patches, height = get_patches(rects_and_attribute, spacing = spacing)
#     379     seqq = get_protein_sequence(_protein)
#     380
#
# ~/Desktop/visualization_project/proj/Data_Visualization/segment_plot.py in get_patches(res_rectangles_and_mods, spacing, colors, standard_height)
#     170                         break
#     171                 if is_available:
# --> 172                     patch = patches.Rectangle((x, i/10), width, standard_height, facecolor = attribute, ec='black', lw=1, alpha=1)
#     173                     for j in range(i, i + int(standard_height * 10) + int(spacing*10)):
#     174                         y_spaces[j] = x + width
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     750             %(Patch_kwdoc)s
#     751         """
# --> 752         super().__init__(**kwargs)
#     753         self._x0 = xy[0]
#     754         self._y0 = xy[1]
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      92         else:
#      93             self.set_edgecolor(edgecolor)
# ---> 94             self.set_facecolor(facecolor)
#      95         # unscaled dashes.  Needed to scale dash patterns by lw
#      96         self._us_dashes = None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in set_facecolor(self, color)
#     366         """
#     367         self._original_facecolor = color
# --> 368         self._set_facecolor(color)
#     369
#     370     def set_color(self, c):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in _set_facecolor(self, color)
#     354             color = mpl.rcParams['patch.facecolor']
#     355         alpha = self._alpha if self._fill else 0
# --> 356         self._facecolor = colors.to_rgba(color, alpha)
#     357         self.stale = True
#     358
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     204         rgba = None
#     205     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 206         rgba = _to_rgba_no_colorcycle(c, alpha)
#     207         try:
#     208             _colors_full_map.cache[c, alpha] = rgba
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     282     # tuple color.
#     283     if not np.iterable(c):
# --> 284         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     285     if len(c) not in [3, 4]:
#     286         raise ValueError("RGBA sequence should have length 3 or 4")
#
# ValueError: Invalid RGBA argument: 0.23209697559440468
