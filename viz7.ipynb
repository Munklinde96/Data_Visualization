# %%
from refactored_utils import get_and_prepare_data
from segment_plot import create_and_plot_segment_plot
from sample_heatmap import create_and_plot_sample_heatmap
from overlap_plots import create_and_plot_overlap_plot, create_and_plot_overlap_heat_map_and_gradient_heatmap

df = get_and_prepare_data()
create_and_plot_segment_plot(df, spacing = 0.2, color_scale ='Blues', is_log_scaled=True, start_end_indices=(16, 40), is_stacked=False)
# create_and_plot_segment_plot(df, spacing = 0.2, color_scale ='Blues', is_log_scaled=True)
# Out:
#     Protein Accession                                            Peptide  \
# 9              P02666  A.RELEELNVPGEIVESLS(+79.97)S(+79.97)S(+79.97)E...
# 23             P02666  A.RELEELNVPGEIVES(+79.97)LSS(+79.97)S(+79.97)E...
# 60             P02666                      A.RELEELNVPGEIVESLSSSEESITR.I
# 116            P02666      A.RELEELNVPGEIVESLSS(+79.97)S(+79.97)EESITR.I
# 143            P02666      A.RELEELNVPGEIVESLS(+79.97)S(+79.97)SEESITR.I
#
#                        PTM  Start  End  Length  Area Sample 1  Area Sample 2  \
# 9    Phosphorylation (STY)     16   40      25     25984000.0      7992900.0
# 23   Phosphorylation (STY)     16   40      25     16722000.0      7992900.0
# 60                     NaN     16   40      25       955650.0       267870.0
# 116  Phosphorylation (STY)     16   40      25      2968600.0       661410.0
# 143  Phosphorylation (STY)     16   40      25       296280.0            NaN
#
#      Area Sample 3  Area Sample 4  #modifications
# 9       15503000.0       476570.0             1.0
# 23      14915000.0            NaN             1.0
# 60        466860.0       696980.0             NaN
# 116       791730.0       548450.0             1.0
# 143      2031300.0            NaN             1.0
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k130
# len of y spaces309
# i+k131
# len of y spaces309
# i+k132
# len of y spaces309
# i+k133
# len of y spaces309
# i+k134
# len of y spaces309
# i+k135
# len of y spaces309
# i+k136
# len of y spaces309
# i+k137
# len of y spaces309
# i+k138
# len of y spaces309
# i+k139
# len of y spaces309
# i+k140
# len of y spaces309
# i+k141
# len of y spaces309
# i+k142
# len of y spaces309
# i+k143
# len of y spaces309
# i+k144
# len of y spaces309
# i+k145
# len of y spaces309
# i+k146
# len of y spaces309
# i+k147
# len of y spaces309
# i+k148
# len of y spaces309
# i+k149
# len of y spaces309
# i+k150
# len of y spaces309
# i+k151
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k130
# len of y spaces309
# i+k131
# len of y spaces309
# i+k132
# len of y spaces309
# i+k133
# len of y spaces309
# i+k134
# len of y spaces309
# i+k135
# len of y spaces309
# i+k136
# len of y spaces309
# i+k137
# len of y spaces309
# i+k138
# len of y spaces309
# i+k139
# len of y spaces309
# i+k140
# len of y spaces309
# i+k141
# len of y spaces309
# i+k142
# len of y spaces309
# i+k143
# len of y spaces309
# i+k144
# len of y spaces309
# i+k145
# len of y spaces309
# i+k146
# len of y spaces309
# i+k147
# len of y spaces309
# i+k148
# len of y spaces309
# i+k149
# len of y spaces309
# i+k150
# len of y spaces309
# i+k151
# len of y spaces309
# i+k152
# len of y spaces309
# i+k153
# len of y spaces309
# i+k154
# len of y spaces309
# i+k155
# len of y spaces309
# i+k156
# len of y spaces309
# i+k157
# len of y spaces309
# i+k158
# len of y spaces309
# i+k159
# len of y spaces309
# i+k160
# len of y spaces309
# i+k161
# len of y spaces309
# i+k162
# len of y spaces309
# i+k163
# len of y spaces309
# i+k164
# len of y spaces309
# i+k165
# len of y spaces309
# i+k166
# len of y spaces309
# i+k167
# len of y spaces309
# i+k168
# len of y spaces309
# i+k169
# len of y spaces309
# i+k170
# len of y spaces309
# i+k171
# len of y spaces309
# i+k172
# len of y spaces309
# i+k173
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k130
# len of y spaces309
# i+k131
# len of y spaces309
# i+k132
# len of y spaces309
# i+k133
# len of y spaces309
# i+k134
# len of y spaces309
# i+k135
# len of y spaces309
# i+k136
# len of y spaces309
# i+k137
# len of y spaces309
# i+k138
# len of y spaces309
# i+k139
# len of y spaces309
# i+k140
# len of y spaces309
# i+k141
# len of y spaces309
# i+k142
# len of y spaces309
# i+k143
# len of y spaces309
# i+k144
# len of y spaces309
# i+k145
# len of y spaces309
# i+k146
# len of y spaces309
# i+k147
# len of y spaces309
# i+k148
# len of y spaces309
# i+k149
# len of y spaces309
# i+k150
# len of y spaces309
# i+k151
# len of y spaces309
# i+k152
# len of y spaces309
# i+k153
# len of y spaces309
# i+k154
# len of y spaces309
# i+k155
# len of y spaces309
# i+k156
# len of y spaces309
# i+k157
# len of y spaces309
# i+k158
# len of y spaces309
# i+k159
# len of y spaces309
# i+k160
# len of y spaces309
# i+k161
# len of y spaces309
# i+k162
# len of y spaces309
# i+k163
# len of y spaces309
# i+k164
# len of y spaces309
# i+k165
# len of y spaces309
# i+k166
# len of y spaces309
# i+k167
# len of y spaces309
# i+k168
# len of y spaces309
# i+k169
# len of y spaces309
# i+k170
# len of y spaces309
# i+k171
# len of y spaces309
# i+k172
# len of y spaces309
# i+k173
# len of y spaces309
# i+k174
# len of y spaces309
# i+k175
# len of y spaces309
# i+k176
# len of y spaces309
# i+k177
# len of y spaces309
# i+k178
# len of y spaces309
# i+k179
# len of y spaces309
# i+k180
# len of y spaces309
# i+k181
# len of y spaces309
# i+k182
# len of y spaces309
# i+k183
# len of y spaces309
# i+k184
# len of y spaces309
# i+k185
# len of y spaces309
# i+k186
# len of y spaces309
# i+k187
# len of y spaces309
# i+k188
# len of y spaces309
# i+k189
# len of y spaces309
# i+k190
# len of y spaces309
# i+k191
# len of y spaces309
# i+k192
# len of y spaces309
# i+k193
# len of y spaces309
# i+k194
# len of y spaces309
# i+k195
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k130
# len of y spaces309
# i+k131
# len of y spaces309
# i+k132
# len of y spaces309
# i+k133
# len of y spaces309
# i+k134
# len of y spaces309
# i+k135
# len of y spaces309
# i+k136
# len of y spaces309
# i+k137
# len of y spaces309
# i+k138
# len of y spaces309
# i+k139
# len of y spaces309
# i+k140
# len of y spaces309
# i+k141
# len of y spaces309
# i+k142
# len of y spaces309
# i+k143
# len of y spaces309
# i+k144
# len of y spaces309
# i+k145
# len of y spaces309
# i+k146
# len of y spaces309
# i+k147
# len of y spaces309
# i+k148
# len of y spaces309
# i+k149
# len of y spaces309
# i+k150
# len of y spaces309
# i+k151
# len of y spaces309
# i+k152
# len of y spaces309
# i+k153
# len of y spaces309
# i+k154
# len of y spaces309
# i+k155
# len of y spaces309
# i+k156
# len of y spaces309
# i+k157
# len of y spaces309
# i+k158
# len of y spaces309
# i+k159
# len of y spaces309
# i+k160
# len of y spaces309
# i+k161
# len of y spaces309
# i+k162
# len of y spaces309
# i+k163
# len of y spaces309
# i+k164
# len of y spaces309
# i+k165
# len of y spaces309
# i+k166
# len of y spaces309
# i+k167
# len of y spaces309
# i+k168
# len of y spaces309
# i+k169
# len of y spaces309
# i+k170
# len of y spaces309
# i+k171
# len of y spaces309
# i+k172
# len of y spaces309
# i+k173
# len of y spaces309
# i+k174
# len of y spaces309
# i+k175
# len of y spaces309
# i+k176
# len of y spaces309
# i+k177
# len of y spaces309
# i+k178
# len of y spaces309
# i+k179
# len of y spaces309
# i+k180
# len of y spaces309
# i+k181
# len of y spaces309
# i+k182
# len of y spaces309
# i+k183
# len of y spaces309
# i+k184
# len of y spaces309
# i+k185
# len of y spaces309
# i+k186
# len of y spaces309
# i+k187
# len of y spaces309
# i+k188
# len of y spaces309
# i+k189
# len of y spaces309
# i+k190
# len of y spaces309
# i+k191
# len of y spaces309
# i+k192
# len of y spaces309
# i+k193
# len of y spaces309
# i+k194
# len of y spaces309
# i+k195
# len of y spaces309
# i+k196
# len of y spaces309
# i+k197
# len of y spaces309
# i+k198
# len of y spaces309
# i+k199
# len of y spaces309
# i+k200
# len of y spaces309
# i+k201
# len of y spaces309
# i+k202
# len of y spaces309
# i+k203
# len of y spaces309
# i+k204
# len of y spaces309
# i+k205
# len of y spaces309
# i+k206
# len of y spaces309
# i+k207
# len of y spaces309
# i+k208
# len of y spaces309
# i+k209
# len of y spaces309
# i+k210
# len of y spaces309
# i+k211
# len of y spaces309
# i+k212
# len of y spaces309
# i+k213
# len of y spaces309
# i+k214
# len of y spaces309
# i+k215
# len of y spaces309
# i+k216
# len of y spaces309
# i+k217
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k130
# len of y spaces309
# i+k131
# len of y spaces309
# i+k132
# len of y spaces309
# i+k133
# len of y spaces309
# i+k134
# len of y spaces309
# i+k135
# len of y spaces309
# i+k136
# len of y spaces309
# i+k137
# len of y spaces309
# i+k138
# len of y spaces309
# i+k139
# len of y spaces309
# i+k140
# len of y spaces309
# i+k141
# len of y spaces309
# i+k142
# len of y spaces309
# i+k143
# len of y spaces309
# i+k144
# len of y spaces309
# i+k145
# len of y spaces309
# i+k146
# len of y spaces309
# i+k147
# len of y spaces309
# i+k148
# len of y spaces309
# i+k149
# len of y spaces309
# i+k150
# len of y spaces309
# i+k151
# len of y spaces309
# i+k152
# len of y spaces309
# i+k153
# len of y spaces309
# i+k154
# len of y spaces309
# i+k155
# len of y spaces309
# i+k156
# len of y spaces309
# i+k157
# len of y spaces309
# i+k158
# len of y spaces309
# i+k159
# len of y spaces309
# i+k160
# len of y spaces309
# i+k161
# len of y spaces309
# i+k162
# len of y spaces309
# i+k163
# len of y spaces309
# i+k164
# len of y spaces309
# i+k165
# len of y spaces309
# i+k166
# len of y spaces309
# i+k167
# len of y spaces309
# i+k168
# len of y spaces309
# i+k169
# len of y spaces309
# i+k170
# len of y spaces309
# i+k171
# len of y spaces309
# i+k172
# len of y spaces309
# i+k173
# len of y spaces309
# i+k174
# len of y spaces309
# i+k175
# len of y spaces309
# i+k176
# len of y spaces309
# i+k177
# len of y spaces309
# i+k178
# len of y spaces309
# i+k179
# len of y spaces309
# i+k180
# len of y spaces309
# i+k181
# len of y spaces309
# i+k182
# len of y spaces309
# i+k183
# len of y spaces309
# i+k184
# len of y spaces309
# i+k185
# len of y spaces309
# i+k186
# len of y spaces309
# i+k187
# len of y spaces309
# i+k188
# len of y spaces309
# i+k189
# len of y spaces309
# i+k190
# len of y spaces309
# i+k191
# len of y spaces309
# i+k192
# len of y spaces309
# i+k193
# len of y spaces309
# i+k194
# len of y spaces309
# i+k195
# len of y spaces309
# i+k196
# len of y spaces309
# i+k197
# len of y spaces309
# i+k198
# len of y spaces309
# i+k199
# len of y spaces309
# i+k200
# len of y spaces309
# i+k201
# len of y spaces309
# i+k202
# len of y spaces309
# i+k203
# len of y spaces309
# i+k204
# len of y spaces309
# i+k205
# len of y spaces309
# i+k206
# len of y spaces309
# i+k207
# len of y spaces309
# i+k208
# len of y spaces309
# i+k209
# len of y spaces309
# i+k210
# len of y spaces309
# i+k211
# len of y spaces309
# i+k212
# len of y spaces309
# i+k213
# len of y spaces309
# i+k214
# len of y spaces309
# i+k215
# len of y spaces309
# i+k216
# len of y spaces309
# i+k217
# len of y spaces309
# i+k218
# len of y spaces309
# i+k219
# len of y spaces309
# i+k220
# len of y spaces309
# i+k221
# len of y spaces309
# i+k222
# len of y spaces309
# i+k223
# len of y spaces309
# i+k224
# len of y spaces309
# i+k225
# len of y spaces309
# i+k226
# len of y spaces309
# i+k227
# len of y spaces309
# i+k228
# len of y spaces309
# i+k229
# len of y spaces309
# i+k230
# len of y spaces309
# i+k231
# len of y spaces309
# i+k232
# len of y spaces309
# i+k233
# len of y spaces309
# i+k234
# len of y spaces309
# i+k235
# len of y spaces309
# i+k236
# len of y spaces309
# i+k237
# len of y spaces309
# i+k238
# len of y spaces309
# i+k239
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k130
# len of y spaces309
# i+k131
# len of y spaces309
# i+k132
# len of y spaces309
# i+k133
# len of y spaces309
# i+k134
# len of y spaces309
# i+k135
# len of y spaces309
# i+k136
# len of y spaces309
# i+k137
# len of y spaces309
# i+k138
# len of y spaces309
# i+k139
# len of y spaces309
# i+k140
# len of y spaces309
# i+k141
# len of y spaces309
# i+k142
# len of y spaces309
# i+k143
# len of y spaces309
# i+k144
# len of y spaces309
# i+k145
# len of y spaces309
# i+k146
# len of y spaces309
# i+k147
# len of y spaces309
# i+k148
# len of y spaces309
# i+k149
# len of y spaces309
# i+k150
# len of y spaces309
# i+k151
# len of y spaces309
# i+k152
# len of y spaces309
# i+k153
# len of y spaces309
# i+k154
# len of y spaces309
# i+k155
# len of y spaces309
# i+k156
# len of y spaces309
# i+k157
# len of y spaces309
# i+k158
# len of y spaces309
# i+k159
# len of y spaces309
# i+k160
# len of y spaces309
# i+k161
# len of y spaces309
# i+k162
# len of y spaces309
# i+k163
# len of y spaces309
# i+k164
# len of y spaces309
# i+k165
# len of y spaces309
# i+k166
# len of y spaces309
# i+k167
# len of y spaces309
# i+k168
# len of y spaces309
# i+k169
# len of y spaces309
# i+k170
# len of y spaces309
# i+k171
# len of y spaces309
# i+k172
# len of y spaces309
# i+k173
# len of y spaces309
# i+k174
# len of y spaces309
# i+k175
# len of y spaces309
# i+k176
# len of y spaces309
# i+k177
# len of y spaces309
# i+k178
# len of y spaces309
# i+k179
# len of y spaces309
# i+k180
# len of y spaces309
# i+k181
# len of y spaces309
# i+k182
# len of y spaces309
# i+k183
# len of y spaces309
# i+k184
# len of y spaces309
# i+k185
# len of y spaces309
# i+k186
# len of y spaces309
# i+k187
# len of y spaces309
# i+k188
# len of y spaces309
# i+k189
# len of y spaces309
# i+k190
# len of y spaces309
# i+k191
# len of y spaces309
# i+k192
# len of y spaces309
# i+k193
# len of y spaces309
# i+k194
# len of y spaces309
# i+k195
# len of y spaces309
# i+k196
# len of y spaces309
# i+k197
# len of y spaces309
# i+k198
# len of y spaces309
# i+k199
# len of y spaces309
# i+k200
# len of y spaces309
# i+k201
# len of y spaces309
# i+k202
# len of y spaces309
# i+k203
# len of y spaces309
# i+k204
# len of y spaces309
# i+k205
# len of y spaces309
# i+k206
# len of y spaces309
# i+k207
# len of y spaces309
# i+k208
# len of y spaces309
# i+k209
# len of y spaces309
# i+k210
# len of y spaces309
# i+k211
# len of y spaces309
# i+k212
# len of y spaces309
# i+k213
# len of y spaces309
# i+k214
# len of y spaces309
# i+k215
# len of y spaces309
# i+k216
# len of y spaces309
# i+k217
# len of y spaces309
# i+k218
# len of y spaces309
# i+k219
# len of y spaces309
# i+k220
# len of y spaces309
# i+k221
# len of y spaces309
# i+k222
# len of y spaces309
# i+k223
# len of y spaces309
# i+k224
# len of y spaces309
# i+k225
# len of y spaces309
# i+k226
# len of y spaces309
# i+k227
# len of y spaces309
# i+k228
# len of y spaces309
# i+k229
# len of y spaces309
# i+k230
# len of y spaces309
# i+k231
# len of y spaces309
# i+k232
# len of y spaces309
# i+k233
# len of y spaces309
# i+k234
# len of y spaces309
# i+k235
# len of y spaces309
# i+k236
# len of y spaces309
# i+k237
# len of y spaces309
# i+k238
# len of y spaces309
# i+k239
# len of y spaces309
# i+k240
# len of y spaces309
# i+k241
# len of y spaces309
# i+k242
# len of y spaces309
# i+k243
# len of y spaces309
# i+k244
# len of y spaces309
# i+k245
# len of y spaces309
# i+k246
# len of y spaces309
# i+k247
# len of y spaces309
# i+k248
# len of y spaces309
# i+k249
# len of y spaces309
# i+k250
# len of y spaces309
# i+k251
# len of y spaces309
# i+k252
# len of y spaces309
# i+k253
# len of y spaces309
# i+k254
# len of y spaces309
# i+k255
# len of y spaces309
# i+k256
# len of y spaces309
# i+k257
# len of y spaces309
# i+k258
# len of y spaces309
# i+k259
# len of y spaces309
# i+k260
# len of y spaces309
# i+k261
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k130
# len of y spaces309
# i+k131
# len of y spaces309
# i+k132
# len of y spaces309
# i+k133
# len of y spaces309
# i+k134
# len of y spaces309
# i+k135
# len of y spaces309
# i+k136
# len of y spaces309
# i+k137
# len of y spaces309
# i+k138
# len of y spaces309
# i+k139
# len of y spaces309
# i+k140
# len of y spaces309
# i+k141
# len of y spaces309
# i+k142
# len of y spaces309
# i+k143
# len of y spaces309
# i+k144
# len of y spaces309
# i+k145
# len of y spaces309
# i+k146
# len of y spaces309
# i+k147
# len of y spaces309
# i+k148
# len of y spaces309
# i+k149
# len of y spaces309
# i+k150
# len of y spaces309
# i+k151
# len of y spaces309
# i+k152
# len of y spaces309
# i+k153
# len of y spaces309
# i+k154
# len of y spaces309
# i+k155
# len of y spaces309
# i+k156
# len of y spaces309
# i+k157
# len of y spaces309
# i+k158
# len of y spaces309
# i+k159
# len of y spaces309
# i+k160
# len of y spaces309
# i+k161
# len of y spaces309
# i+k162
# len of y spaces309
# i+k163
# len of y spaces309
# i+k164
# len of y spaces309
# i+k165
# len of y spaces309
# i+k166
# len of y spaces309
# i+k167
# len of y spaces309
# i+k168
# len of y spaces309
# i+k169
# len of y spaces309
# i+k170
# len of y spaces309
# i+k171
# len of y spaces309
# i+k172
# len of y spaces309
# i+k173
# len of y spaces309
# i+k174
# len of y spaces309
# i+k175
# len of y spaces309
# i+k176
# len of y spaces309
# i+k177
# len of y spaces309
# i+k178
# len of y spaces309
# i+k179
# len of y spaces309
# i+k180
# len of y spaces309
# i+k181
# len of y spaces309
# i+k182
# len of y spaces309
# i+k183
# len of y spaces309
# i+k184
# len of y spaces309
# i+k185
# len of y spaces309
# i+k186
# len of y spaces309
# i+k187
# len of y spaces309
# i+k188
# len of y spaces309
# i+k189
# len of y spaces309
# i+k190
# len of y spaces309
# i+k191
# len of y spaces309
# i+k192
# len of y spaces309
# i+k193
# len of y spaces309
# i+k194
# len of y spaces309
# i+k195
# len of y spaces309
# i+k196
# len of y spaces309
# i+k197
# len of y spaces309
# i+k198
# len of y spaces309
# i+k199
# len of y spaces309
# i+k200
# len of y spaces309
# i+k201
# len of y spaces309
# i+k202
# len of y spaces309
# i+k203
# len of y spaces309
# i+k204
# len of y spaces309
# i+k205
# len of y spaces309
# i+k206
# len of y spaces309
# i+k207
# len of y spaces309
# i+k208
# len of y spaces309
# i+k209
# len of y spaces309
# i+k210
# len of y spaces309
# i+k211
# len of y spaces309
# i+k212
# len of y spaces309
# i+k213
# len of y spaces309
# i+k214
# len of y spaces309
# i+k215
# len of y spaces309
# i+k216
# len of y spaces309
# i+k217
# len of y spaces309
# i+k218
# len of y spaces309
# i+k219
# len of y spaces309
# i+k220
# len of y spaces309
# i+k221
# len of y spaces309
# i+k222
# len of y spaces309
# i+k223
# len of y spaces309
# i+k224
# len of y spaces309
# i+k225
# len of y spaces309
# i+k226
# len of y spaces309
# i+k227
# len of y spaces309
# i+k228
# len of y spaces309
# i+k229
# len of y spaces309
# i+k230
# len of y spaces309
# i+k231
# len of y spaces309
# i+k232
# len of y spaces309
# i+k233
# len of y spaces309
# i+k234
# len of y spaces309
# i+k235
# len of y spaces309
# i+k236
# len of y spaces309
# i+k237
# len of y spaces309
# i+k238
# len of y spaces309
# i+k239
# len of y spaces309
# i+k240
# len of y spaces309
# i+k241
# len of y spaces309
# i+k242
# len of y spaces309
# i+k243
# len of y spaces309
# i+k244
# len of y spaces309
# i+k245
# len of y spaces309
# i+k246
# len of y spaces309
# i+k247
# len of y spaces309
# i+k248
# len of y spaces309
# i+k249
# len of y spaces309
# i+k250
# len of y spaces309
# i+k251
# len of y spaces309
# i+k252
# len of y spaces309
# i+k253
# len of y spaces309
# i+k254
# len of y spaces309
# i+k255
# len of y spaces309
# i+k256
# len of y spaces309
# i+k257
# len of y spaces309
# i+k258
# len of y spaces309
# i+k259
# len of y spaces309
# i+k260
# len of y spaces309
# i+k261
# len of y spaces309
# i+k262
# len of y spaces309
# i+k263
# len of y spaces309
# i+k264
# len of y spaces309
# i+k265
# len of y spaces309
# i+k266
# len of y spaces309
# i+k267
# len of y spaces309
# i+k268
# len of y spaces309
# i+k269
# len of y spaces309
# i+k270
# len of y spaces309
# i+k271
# len of y spaces309
# i+k272
# len of y spaces309
# i+k273
# len of y spaces309
# i+k274
# len of y spaces309
# i+k275
# len of y spaces309
# i+k276
# len of y spaces309
# i+k277
# len of y spaces309
# i+k278
# len of y spaces309
# i+k279
# len of y spaces309
# i+k280
# len of y spaces309
# i+k281
# len of y spaces309
# i+k282
# len of y spaces309
# i+k283
# len of y spaces309
# i+k0
# len of y spaces309
# i+k1
# len of y spaces309
# i+k2
# len of y spaces309
# i+k3
# len of y spaces309
# i+k4
# len of y spaces309
# i+k5
# len of y spaces309
# i+k6
# len of y spaces309
# i+k7
# len of y spaces309
# i+k8
# len of y spaces309
# i+k9
# len of y spaces309
# i+k10
# len of y spaces309
# i+k11
# len of y spaces309
# i+k12
# len of y spaces309
# i+k13
# len of y spaces309
# i+k14
# len of y spaces309
# i+k15
# len of y spaces309
# i+k16
# len of y spaces309
# i+k17
# len of y spaces309
# i+k18
# len of y spaces309
# i+k19
# len of y spaces309
# i+k20
# len of y spaces309
# i+k21
# len of y spaces309
# i+k22
# len of y spaces309
# i+k23
# len of y spaces309
# i+k24
# len of y spaces309
# i+k25
# len of y spaces309
# i+k26
# len of y spaces309
# i+k27
# len of y spaces309
# i+k28
# len of y spaces309
# i+k29
# len of y spaces309
# i+k30
# len of y spaces309
# i+k31
# len of y spaces309
# i+k32
# len of y spaces309
# i+k33
# len of y spaces309
# i+k34
# len of y spaces309
# i+k35
# len of y spaces309
# i+k36
# len of y spaces309
# i+k37
# len of y spaces309
# i+k38
# len of y spaces309
# i+k39
# len of y spaces309
# i+k40
# len of y spaces309
# i+k41
# len of y spaces309
# i+k42
# len of y spaces309
# i+k43
# len of y spaces309
# i+k44
# len of y spaces309
# i+k45
# len of y spaces309
# i+k46
# len of y spaces309
# i+k47
# len of y spaces309
# i+k48
# len of y spaces309
# i+k49
# len of y spaces309
# i+k50
# len of y spaces309
# i+k51
# len of y spaces309
# i+k52
# len of y spaces309
# i+k53
# len of y spaces309
# i+k54
# len of y spaces309
# i+k55
# len of y spaces309
# i+k56
# len of y spaces309
# i+k57
# len of y spaces309
# i+k58
# len of y spaces309
# i+k59
# len of y spaces309
# i+k60
# len of y spaces309
# i+k61
# len of y spaces309
# i+k62
# len of y spaces309
# i+k63
# len of y spaces309
# i+k64
# len of y spaces309
# i+k65
# len of y spaces309
# i+k66
# len of y spaces309
# i+k67
# len of y spaces309
# i+k68
# len of y spaces309
# i+k69
# len of y spaces309
# i+k70
# len of y spaces309
# i+k71
# len of y spaces309
# i+k72
# len of y spaces309
# i+k73
# len of y spaces309
# i+k74
# len of y spaces309
# i+k75
# len of y spaces309
# i+k76
# len of y spaces309
# i+k77
# len of y spaces309
# i+k78
# len of y spaces309
# i+k79
# len of y spaces309
# i+k80
# len of y spaces309
# i+k81
# len of y spaces309
# i+k82
# len of y spaces309
# i+k83
# len of y spaces309
# i+k84
# len of y spaces309
# i+k85
# len of y spaces309
# i+k86
# len of y spaces309
# i+k87
# len of y spaces309
# i+k88
# len of y spaces309
# i+k89
# len of y spaces309
# i+k90
# len of y spaces309
# i+k91
# len of y spaces309
# i+k92
# len of y spaces309
# i+k93
# len of y spaces309
# i+k94
# len of y spaces309
# i+k95
# len of y spaces309
# i+k96
# len of y spaces309
# i+k97
# len of y spaces309
# i+k98
# len of y spaces309
# i+k99
# len of y spaces309
# i+k100
# len of y spaces309
# i+k101
# len of y spaces309
# i+k102
# len of y spaces309
# i+k103
# len of y spaces309
# i+k104
# len of y spaces309
# i+k105
# len of y spaces309
# i+k106
# len of y spaces309
# i+k107
# len of y spaces309
# i+k108
# len of y spaces309
# i+k109
# len of y spaces309
# i+k110
# len of y spaces309
# i+k111
# len of y spaces309
# i+k112
# len of y spaces309
# i+k113
# len of y spaces309
# i+k114
# len of y spaces309
# i+k115
# len of y spaces309
# i+k116
# len of y spaces309
# i+k117
# len of y spaces309
# i+k118
# len of y spaces309
# i+k119
# len of y spaces309
# i+k120
# len of y spaces309
# i+k121
# len of y spaces309
# i+k122
# len of y spaces309
# i+k123
# len of y spaces309
# i+k124
# len of y spaces309
# i+k125
# len of y spaces309
# i+k126
# len of y spaces309
# i+k127
# len of y spaces309
# i+k128
# len of y spaces309
# i+k129
# len of y spaces309
# i+k130
# len of y spaces309
# i+k131
# len of y spaces309
# i+k132
# len of y spaces309
# i+k133
# len of y spaces309
# i+k134
# len of y spaces309
# i+k135
# len of y spaces309
# i+k136
# len of y spaces309
# i+k137
# len of y spaces309
# i+k138
# len of y spaces309
# i+k139
# len of y spaces309
# i+k140
# len of y spaces309
# i+k141
# len of y spaces309
# i+k142
# len of y spaces309
# i+k143
# len of y spaces309
# i+k144
# len of y spaces309
# i+k145
# len of y spaces309
# i+k146
# len of y spaces309
# i+k147
# len of y spaces309
# i+k148
# len of y spaces309
# i+k149
# len of y spaces309
# i+k150
# len of y spaces309
# i+k151
# len of y spaces309
# i+k152
# len of y spaces309
# i+k153
# len of y spaces309
# i+k154
# len of y spaces309
# i+k155
# len of y spaces309
# i+k156
# len of y spaces309
# i+k157
# len of y spaces309
# i+k158
# len of y spaces309
# i+k159
# len of y spaces309
# i+k160
# len of y spaces309
# i+k161
# len of y spaces309
# i+k162
# len of y spaces309
# i+k163
# len of y spaces309
# i+k164
# len of y spaces309
# i+k165
# len of y spaces309
# i+k166
# len of y spaces309
# i+k167
# len of y spaces309
# i+k168
# len of y spaces309
# i+k169
# len of y spaces309
# i+k170
# len of y spaces309
# i+k171
# len of y spaces309
# i+k172
# len of y spaces309
# i+k173
# len of y spaces309
# i+k174
# len of y spaces309
# i+k175
# len of y spaces309
# i+k176
# len of y spaces309
# i+k177
# len of y spaces309
# i+k178
# len of y spaces309
# i+k179
# len of y spaces309
# i+k180
# len of y spaces309
# i+k181
# len of y spaces309
# i+k182
# len of y spaces309
# i+k183
# len of y spaces309
# i+k184
# len of y spaces309
# i+k185
# len of y spaces309
# i+k186
# len of y spaces309
# i+k187
# len of y spaces309
# i+k188
# len of y spaces309
# i+k189
# len of y spaces309
# i+k190
# len of y spaces309
# i+k191
# len of y spaces309
# i+k192
# len of y spaces309
# i+k193
# len of y spaces309
# i+k194
# len of y spaces309
# i+k195
# len of y spaces309
# i+k196
# len of y spaces309
# i+k197
# len of y spaces309
# i+k198
# len of y spaces309
# i+k199
# len of y spaces309
# i+k200
# len of y spaces309
# i+k201
# len of y spaces309
# i+k202
# len of y spaces309
# i+k203
# len of y spaces309
# i+k204
# len of y spaces309
# i+k205
# len of y spaces309
# i+k206
# len of y spaces309
# i+k207
# len of y spaces309
# i+k208
# len of y spaces309
# i+k209
# len of y spaces309
# i+k210
# len of y spaces309
# i+k211
# len of y spaces309
# i+k212
# len of y spaces309
# i+k213
# len of y spaces309
# i+k214
# len of y spaces309
# i+k215
# len of y spaces309
# i+k216
# len of y spaces309
# i+k217
# len of y spaces309
# i+k218
# len of y spaces309
# i+k219
# len of y spaces309
# i+k220
# len of y spaces309
# i+k221
# len of y spaces309
# i+k222
# len of y spaces309
# i+k223
# len of y spaces309
# i+k224
# len of y spaces309
# i+k225
# len of y spaces309
# i+k226
# len of y spaces309
# i+k227
# len of y spaces309
# i+k228
# len of y spaces309
# i+k229
# len of y spaces309
# i+k230
# len of y spaces309
# i+k231
# len of y spaces309
# i+k232
# len of y spaces309
# i+k233
# len of y spaces309
# i+k234
# len of y spaces309
# i+k235
# len of y spaces309
# i+k236
# len of y spaces309
# i+k237
# len of y spaces309
# i+k238
# len of y spaces309
# i+k239
# len of y spaces309
# i+k240
# len of y spaces309
# i+k241
# len of y spaces309
# i+k242
# len of y spaces309
# i+k243
# len of y spaces309
# i+k244
# len of y spaces309
# i+k245
# len of y spaces309
# i+k246
# len of y spaces309
# i+k247
# len of y spaces309
# i+k248
# len of y spaces309
# i+k249
# len of y spaces309
# i+k250
# len of y spaces309
# i+k251
# len of y spaces309
# i+k252
# len of y spaces309
# i+k253
# len of y spaces309
# i+k254
# len of y spaces309
# i+k255
# len of y spaces309
# i+k256
# len of y spaces309
# i+k257
# len of y spaces309
# i+k258
# len of y spaces309
# i+k259
# len of y spaces309
# i+k260
# len of y spaces309
# i+k261
# len of y spaces309
# i+k262
# len of y spaces309
# i+k263
# len of y spaces309
# i+k264
# len of y spaces309
# i+k265
# len of y spaces309
# i+k266
# len of y spaces309
# i+k267
# len of y spaces309
# i+k268
# len of y spaces309
# i+k269
# len of y spaces309
# i+k270
# len of y spaces309
# i+k271
# len of y spaces309
# i+k272
# len of y spaces309
# i+k273
# len of y spaces309
# i+k274
# len of y spaces309
# i+k275
# len of y spaces309
# i+k276
# len of y spaces309
# i+k277
# len of y spaces309
# i+k278
# len of y spaces309
# i+k279
# len of y spaces309
# i+k280
# len of y spaces309
# i+k281
# len of y spaces309
# i+k282
# len of y spaces309
# i+k283
# len of y spaces309
# i+k284
# len of y spaces309
# i+k285
# len of y spaces309
# i+k286
# len of y spaces309
# i+k287
# len of y spaces309
# i+k288
# len of y spaces309
# i+k289
# len of y spaces309
# i+k290
# len of y spaces309
# i+k291
# len of y spaces309
# i+k292
# len of y spaces309
# i+k293
# len of y spaces309
# i+k294
# len of y spaces309
# i+k295
# len of y spaces309
# i+k296
# len of y spaces309
# i+k297
# len of y spaces309
# i+k298
# len of y spaces309
# i+k299
# len of y spaces309
# i+k300
# len of y spaces309
# i+k301
# len of y spaces309
# i+k302
# len of y spaces309
# i+k303
# len of y spaces309
# i+k304
# len of y spaces309
# i+k305

# %%
create_and_plot_overlap_plot(df)

# %%
create_and_plot_overlap_heat_map_and_gradient_heatmap(df)

# %%
create_and_plot_sample_heatmap(df)

# %%
from refactored_utils import get_and_prepare_data
from segment_plot import create_and_plot_segment_plot
from sample_heatmap import create_and_plot_sample_heatmap
from overlap_plots import create_and_plot_overlap_plot, create_and_plot_overlap_heat_map_and_gradient_heatmap

df = get_and_prepare_data()
create_and_plot_segment_plot(df, spacing = 0.2, is_log_scaled=True, colors = False)
# Out:
# 183 114
# 2 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-bdadd3ebc60b> in <module>
#       5
#       6 df = get_and_prepare_data()
# ----> 7 create_and_plot_segment_plot(df, spacing = 0.2, is_log_scaled=True, colors = False)
#
# c:\Users\chris\Documents\7. Semester\Data Visualization\Data_Visualization\segment_plot.py in create_and_plot_segment_plot(df, _protein, spacing, colors, color_scale, is_log_scaled, standard_height)
#     304     print(min_ind, max_ind)
#     305     print(peptide_patches[min_ind][3], peptide_patches[max_ind][3])
# --> 306     peptide_patches, mod_patches = get_patches_from_patch_attributes(peptide_patches, mod_patches)
#     307     plot_peptide_segments(peptide_patches, mod_patches, height, modification_color_map, colors = colors, color_scale=color_scale, is_log_scaled=is_log_scaled, _protein = _protein)
#     308
#
# c:\Users\chris\Documents\7. Semester\Data Visualization\Data_Visualization\segment_plot.py in get_patches_from_patch_attributes(peptide_patches, mod_patches)
#     245     for i in range(len(peptide_patches)):
#     246         x, y, width, height, color = peptide_patches[i]
# --> 247         patch = patches.Rectangle((x, y), width, height, facecolor = color, ec='black', lw=1, alpha=1)
#     248         peptide_patches_list.append(patch)
#     249     for i in range(len(mod_patches)):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     705         """
#     706
# --> 707         Patch.__init__(self, **kwargs)
#     708
#     709         self._x0 = xy[0]
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      80         else:
#      81             self.set_edgecolor(edgecolor)
# ---> 82             self.set_facecolor(facecolor)
#      83         # unscaled dashes.  Needed to scale dash patterns by lw
#      84         self._us_dashes = None
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in set_facecolor(self, color)
#     317         """
#     318         self._original_facecolor = color
# --> 319         self._set_facecolor(color)
#     320
#     321     def set_color(self, c):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in _set_facecolor(self, color)
#     305             color = mpl.rcParams['patch.facecolor']
#     306         alpha = self._alpha if self._fill else 0
# --> 307         self._facecolor = colors.to_rgba(color, alpha)
#     308         self.stale = True
#     309
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     175         rgba = None
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#     179             _colors_full_map.cache[c, alpha] = rgba
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     238         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     239         # Test dimensionality to reject single floats.
# --> 240         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     241     # Return a tuple to prevent the cached value from being modified.
#     242     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: 0.23209697559440468
